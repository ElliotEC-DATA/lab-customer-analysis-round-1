# %%
import pandas as pd
df1 = pd.read_csv('/Users/accountmanager/Desktop/Iron Hack/Unit_1/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')

# %%
df2 = pd.read_csv('/Users/accountmanager/Desktop/Iron Hack/Unit_1/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')

# %%
df3 = pd.read_csv('/Users/accountmanager/Desktop/Iron Hack/Unit_1/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %%
df1
# Out:
#      customer       state gender             education       gender   income  \
# 0     RB50392  Washington    NaN                Master          NaN      0.0
# 1     QZ44356     Arizona      F              Bachelor   697953.59%      0.0
# 2     AI49188      Nevada      F              Bachelor  1288743.17%  48767.0
# 3     WW63253  California      M              Bachelor   764586.18%      0.0
# 4     GA49547  Washington      M  High School or Below   536307.65%  36357.0
# ...       ...         ...    ...                   ...          ...      ...
# 4003      NaN         NaN    NaN                   NaN          NaN      NaN
# 4004      NaN         NaN    NaN                   NaN          NaN      NaN
# 4005      NaN         NaN    NaN                   NaN          NaN      NaN
# 4006      NaN         NaN    NaN                   NaN          NaN      NaN
# 4007      NaN         NaN    NaN                   NaN          NaN      NaN
#
# ...

# %%
df2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
df3
# Out:
#      customer       state gender             education gender  income  \
# 0     SA25987  Washington      M  High School or Below      M       0
# 1     TB86706     Arizona      M                Master      M       0
# 2     ZL73902      Nevada      F              Bachelor      F   25820
# 3     KX23516  California      F  High School or Below      F       0
# 4     FN77294  California      M  High School or Below      M   30366
# ...       ...         ...    ...                   ...    ...     ...
# 7065  LA72316  California      M              Bachelor      M   71941
# 7066  PK87824  California      F               College      F   21604
# 7067  TD14365  California      M              Bachelor      M       0
# 7068  UP19263  California      M               College      M   21941
# 7069  Y167826  California      M               College      M       0
#
#       monthly premium auto  number of open complaints     policy type  \
# ...

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()

# %%
titles = list(df2.columns)
titles [8], titles [9], titles [10] = titles [9], titles [10], titles [8]
df2 = df2[titles]

# %%
titles2 = list(df3.columns)
titles2 [2], titles2 [4], titles2[9], titles2 [10] = titles2 [4], titles2 [4], titles2[10], titles2 [9]
df3 = df3[titles2]

# %%
# column 0,4,5,6,7,10 are numerical and the others are categorical
df1.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
# customer : unique ID, st : state, gender : sexe, education : school
# customer lifetime value : amount of benefices of client in is lifetime, income :  money that comes
# monthly premium auto : amount that has been paid every month, Nb of open com... : amount of complaints
# policy type : well it is the different policies that exists, same for vehicle class
# total claim amount : amount the client is asking, state : place

# %%
data = pd.concat([df1, df2, df3]) # I've searched on many websites and youtube what was the problem and - 
# - I coudn't find why there is this mistake and ohow to solve it...
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 data = pd.concat([df1, df2, df3])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
# ...
